# %%
import pandas as pd

# %%
f = r"F:\Dropbox (Personal)\BCII\BCI Challenges\2024 ALVI EMG Decoding\submit_gt.csv"

df = pd.read_csv(f)

print(df.shape)
df.head()
# Out:
# (26829, 20)
#           0         1         2         3         4         5         6  \
# 0 -0.940073 -0.006680  1.547762  0.715244 -0.275635  0.037491  0.476829
# 1 -0.943642 -0.007023  1.548695  0.713961 -0.285192  0.037644  0.480748
# 2 -0.943809 -0.007086  1.549352  0.714324 -0.288916  0.037730  0.485022
# 3 -0.943948 -0.007170  1.550651  0.715434 -0.291395  0.037971  0.486921
# 4 -0.944021 -0.007179  1.551846  0.716411 -0.296242  0.038577  0.487375
#
#           7         8         9        10        11        12        13  \
# 0  0.052841  0.108835  0.036273  0.532043  0.229802  0.509256 -0.002389
# 1  0.052106  0.108515  0.037295  0.533613  0.226893  0.518311  0.003914
# 2  0.053114  0.109243  0.037551  0.534834  0.225893  0.523289  0.006490
# 3  0.054009  0.110545  0.038499  0.537378  0.226248  0.528933  0.010701
# 4  0.053679  0.106117  0.040575  0.546809  0.229721  0.532626  0.018017
#
#          14        15        16        17        18        19
# ...

# %%
# add a new first column a "sample_id" column
df.insert(0, "sample_id", range(1, 1 + len(df)))

df.head()
# Out:
#    sample_id         0         1         2         3         4         5  \
# 0          1 -0.940073 -0.006680  1.547762  0.715244 -0.275635  0.037491
# 1          2 -0.943642 -0.007023  1.548695  0.713961 -0.285192  0.037644
# 2          3 -0.943809 -0.007086  1.549352  0.714324 -0.288916  0.037730
# 3          4 -0.943948 -0.007170  1.550651  0.715434 -0.291395  0.037971
# 4          5 -0.944021 -0.007179  1.551846  0.716411 -0.296242  0.038577
#
#           6         7         8  ...        10        11        12        13  \
# 0  0.476829  0.052841  0.108835  ...  0.532043  0.229802  0.509256 -0.002389
# 1  0.480748  0.052106  0.108515  ...  0.533613  0.226893  0.518311  0.003914
# 2  0.485022  0.053114  0.109243  ...  0.534834  0.225893  0.523289  0.006490
# 3  0.486921  0.054009  0.110545  ...  0.537378  0.226248  0.528933  0.010701
# 4  0.487375  0.053679  0.106117  ...  0.546809  0.229721  0.532626  0.018017
#
#          14        15        16        17        18        19
# ...

# %%
# add an Usage column with half the data as "Public" and the other half as "Private"
df["Usage"] = "Public"


# make the second half of the df private
df.loc[df.index > len(df) // 2, "Usage"] = "Private"

df.head()
# Out:
#    sample_id         0         1         2         3         4         5  \
# 0          1 -0.940073 -0.006680  1.547762  0.715244 -0.275635  0.037491
# 1          2 -0.943642 -0.007023  1.548695  0.713961 -0.285192  0.037644
# 2          3 -0.943809 -0.007086  1.549352  0.714324 -0.288916  0.037730
# 3          4 -0.943948 -0.007170  1.550651  0.715434 -0.291395  0.037971
# 4          5 -0.944021 -0.007179  1.551846  0.716411 -0.296242  0.038577
#
#           6         7         8  ...        11        12        13        14  \
# 0  0.476829  0.052841  0.108835  ...  0.229802  0.509256 -0.002389  0.414984
# 1  0.480748  0.052106  0.108515  ...  0.226893  0.518311  0.003914  0.421842
# 2  0.485022  0.053114  0.109243  ...  0.225893  0.523289  0.006490  0.426143
# 3  0.486921  0.054009  0.110545  ...  0.226248  0.528933  0.010701  0.431467
# 4  0.487375  0.053679  0.106117  ...  0.229721  0.532626  0.018017  0.439766
#
#          15        16        17        18        19   Usage
# ...

# %%
df.tail()
# Out:
#        sample_id         0         1         2         3         4         5  \
# 26824      26825  0.222789 -0.130912  0.296158 -0.067957 -0.670833 -0.022100
# 26825      26826  0.221792 -0.131321  0.296632 -0.067788 -0.671213 -0.022129
# 26826      26827  0.217293 -0.131536  0.296930 -0.068013 -0.675350 -0.021762
# 26827      26828  0.215185 -0.130896  0.296864 -0.068015 -0.676020 -0.021672
# 26828      26829  0.216600 -0.129904  0.295894 -0.068510 -0.674005 -0.021620
#
#               6         7         8  ...        11        12        13  \
# 26824  1.650532  0.812179 -0.738611  ...  0.884676 -0.764260  0.044247
# 26825  1.651170  0.811587 -0.739702  ...  0.882868 -0.767509  0.044275
# 26826  1.655264  0.812157 -0.741224  ...  0.881817 -0.767172  0.044415
# 26827  1.655445  0.812439 -0.740912  ...  0.882915 -0.765399  0.044517
# 26828  1.653043  0.812097 -0.740050  ...  0.884068 -0.764274  0.044341
#
#              14        15        16        17        18        19    Usage
# ...

# %%
assert len(df['sample_id'].unique()) == len(df['sample_id'])

# %%
f = r"F:\Dropbox (Personal)\BCII\BCI Challenges\2024 ALVI EMG Decoding\submit_gt_edited.csv"
df.to_csv(f, index=False)

# %%
# make everything except sample_id a 0
df.iloc[:, 1:] = 0

# remove usage
df = df.drop(columns=["Usage"])

f = r"F:\Dropbox (Personal)\BCII\BCI Challenges\2024 ALVI EMG Decoding\submit_sample.csv"
df.to_csv(f, index=False)
